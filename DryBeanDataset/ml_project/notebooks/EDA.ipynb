# %%
# EDA: Dry Bean Dataset 全流程项目笔记本

本笔记本包含环境说明、数据加载、缺失值与类别分布检查、特征分布与相关性、初步结论。
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

DATA_DIR = Path('..') / '..'
TRAIN_CSV = DATA_DIR / 'Dry_Bean_Dataset_Dirty_train.csv'
VAL_CSV = DATA_DIR / 'Dry_Bean_Dataset_Dirty_val.csv'
TEST_CSV = DATA_DIR / 'Dry_Bean_Dataset_Dirty_test.csv'

print('Train CSV:', TRAIN_CSV)

# 读取前几行检查
train_head = pd.read_csv(TRAIN_CSV, nrows=5)
train_head
